# %% [markdown]
# Introduction to Matplotlib
# ==

# %%
import logging,sys
print("Let's run some code.")

print("Sure :)")

n = 1+1
print(n)

print(Oops)
# Out:
# Let's run some code.
# Sure :)
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c8a81a5ecb8> in <module>()
#       7 print(n)
#       8
# ----> 9 print(Oops)
#
# NameError: name 'Oops' is not defined

# %% [raw]
# # Warning: This is an infinite loop! Please do not run or stop right away!
# While 1:
#     print("Stop me! >.<")

# %%
import matplotlib.pyplot as plt

x = list(range(10))
y = [i**2 for i in x]

plt.plot(x,y)
plt.show()

# %% [markdown]
# Title: My first notebook <!--Press 'Run' or Shift+Enter for the following output-->
# ==
# # Header 1
# ## Header 2
#
# This is the content of my notebook.
#
# I am __BOLD__.
# - I want to make a point
# * so do I
#
# 1. Let's have some order here
# 2. Some *more* order
#     - I need some hierarchy
#     *italic. Isn't it chic?*
#
# > I love Python :D
#
# ```
# print("Hello World")
# print("I am ready to learn Matplotlib")
# ```
# ---
